# %%
import numpy as np
from matplotlib import pyplot as plt

from FunctionCompiler import *
from Objects import JJ, Ib

# %%
JJ1 = JJ.JJ(loc=[1, 0], c=1, r=1, A=1)
ib1 = Ib.Ib(loc=[1,0], val=1.5)

t = np.linspace(0, 300, 10000)
fc = FunctionCompiler([JJ1, ib1], t)
# Out:
# Generated objects are: JJ1 Ib1

# %%
sol = fc.solve()

# %%
V_JJ = JJ1.get_data('V', t, sol)
plt.plot(t, V_JJ)

# %%
JJ1.data_index
# Out:
# [1, 0]

# %%
JJ1.current_index
# Out:
# 2

# %%
JJ1.var_index
# Out:
# 2

# %%
sol[1,:]
# Out:
# array([-0.005     , -2.0019469 , -1.49277702, ..., -1.49668388,
#        -1.49668388, -1.49668388])

# %%
fc.m, fc.n, fc.i
# Out:
# (1, 1, 1)

# %%
JJ1.get_matrix_stamp(0.01)
# Out:
# array([[   0.,    0.,    1.],
#        [   1., -150.,    0.],
#        [   2.,    0.,   -1.]])

# %%
ib1.var_index
# Out:
# -1

# %%
JJ1.current_index
# Out:
# 2

# %%
JJ1.var_index
# Out:
# 1

# %%
JJ1.data_index
# Out:
# [1, 0]

# %%
V_JJ
# Out:
# array([-0.005     , -2.0019469 , -1.49277702, ..., -1.49668388,
#        -1.49668388, -1.49668388])

# %%
sol.shape
# Out:
# (3, 300000)
